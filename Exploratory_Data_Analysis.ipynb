# %%
import pandas as pd 
import psycopg2

# %% [markdown]
# making a connection with the database

# %%
conn=psycopg2.connect(
    host="localhost",
    database="inventory_db2",
    user="postgres",
    password="Layappa123@",
    port="5432"
)

# %% [markdown]
# cursor to execute sql quaries

# %%
cur=conn.cursor()
cur.execute("""
 SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'public';
""")

# %% [markdown]
# below code fetches result from the result

# %%
tables=cur.fetchall()
for table in tables:
    print(table[0])
# Out:
# begin_inventory
# end_inventory
# purchases
# purchase_prices
# sales
# vendor_invoice

# %%
import warnings
warnings.filterwarnings("ignore")

for table in tables:
    print('-'*50,f'{table[0]}','-'*50)
    print("count of rows",pd.read_sql(f"select count(*) from {table[0]}",conn)['count'].values[0])
    display(pd.read_sql(f"select * from {table[0]} limit 5;",conn))
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# count of rows 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------------------------------------- end_inventory --------------------------------------------------
# count of rows 224489
# ...
