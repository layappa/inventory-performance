# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %% [markdown]
# convering special charecter in the password usif urllb

# %%
from urllib.parse import quote_plus

# %%
user_name='postgres'
password='Layappa123@'
encoded_password=quote_plus(password)
port=5432
host='localhost'

# %% [markdown]
# creating engine for pushing data to postgresql

# %%
engine=create_engine(f"postgresql+psycopg2://{user_name}:{encoded_password}@{host}:{port}/inventory")

# %% [markdown]
# function to insert datafreame into sql

# %%
def ingest_df(df,table,engine):
    df.to_sql(table,con=engine,if_exists='replace',index=False)

# %% [markdown]
# inserting dataset into sql

# %%
for file in os.listdir('data'):
    if '.csv' in file :
        df=pd.read_csv('data/'+file)
        ingest_df(df,file[:-4],engine)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\layap\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:1811, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1809         conn = self._revalidate_connection()
# -> 1811     context = constructor(
#    1812         dialect, self, conn, execution_options, *args, **kw
#    1813     )
#    1814 except (exc.PendingRollbackError, exc.ResourceClosedError):
#
# File c:\Users\layap\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\default.py:1405, in DefaultExecutionContext._init_compiled(cls, dialect, connection, dbapi_connection, execution_options, compiled, parameters, invoked_statement, extracted_parameters, cache_hit)
#    1404 else:
# -> 1405     self.compiled_parameters = [
# ...

# %%
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47      NaN
# 1  2023-12-22  2024-02-21        15     140.55     8.57      NaN
# 2  2023-12-24  2024-02-16         5     106.60     4.61      NaN
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20      NaN
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20      NaN
